# %%
import numpy as np
from numpy.fft import fft
import matplotlib.pyplot as plt
import scipy.io.wavfile as spwav
#from mpldatacursor import datacursor
import sys

plt.style.use('ggplot')

# Note: this epoch list only holds for "test_vector_all_voiced.wav"
epoch_marks_orig = np.load("test_vector_all_voiced_epochs.npy")
F_s, audio_data = spwav.read("test_vector_all_voiced.wav")
print(F_s)
N = len(audio_data)
plt.plot(audio_data, 'g')
plt.title("Original AudioData")
plt.show()
# Out:
# 44100

# %%
######################## YOUR CODE HERE ##############################

F_new = 420
new_epoch_spacing = int(F_s/F_new)  #P1
audio_out = np.zeros(N)

# Suggested loop
for i in range(0, N, new_epoch_spacing):
    
    #Step1: find closest epoch     
    e = np.argmin(abs(epoch_marks_orig - i))  #index
    cloest_e = epoch_marks_orig[e]            #value
    if(e == 0 or e == len(epoch_marks_orig)-1):
        pass
    else:
        #find P_0 from previous and next epochs distance
        before = epoch_marks_orig[e - 1]
        after = epoch_marks_orig[e+1]
        P_0 = int((after - before) / 2)

        #put new data in audio_out
        data = audio_data[(cloest_e - P_0):(cloest_e + P_0+1)]
        window = np.hanning(2 * P_0 + 1)
        windowed_response = window * data
        audio_out[i-P_0:(i + P_0 + 1)] += windowed_response

# %%
plt.plot(audio_out, 'b')
plt.title("F_new = 420")
plt.show()
from IPython.display import Audio
Audio(audio_out, rate=F_s)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
######################## YOUR CODE HERE ##############################

F_new = 100
new_epoch_spacing = int(F_s/F_new)  #P1
audio_out = np.zeros(N)

# Suggested loop
for i in range(0, N, new_epoch_spacing):
    
    #Step1: find closest epoch     
    e = np.argmin(abs(epoch_marks_orig - i))  #index
    cloest_e = epoch_marks_orig[e]            #value
    if(e == 0 or e == len(epoch_marks_orig)-1):
        pass
    else:
        #find P_0 from previous and next epochs distance
        before = epoch_marks_orig[e - 1]
        after = epoch_marks_orig[e+1]
        P_0 = int((after - before) / 2)

        #put new data in audio_out
        data = audio_data[(cloest_e - P_0):(cloest_e + P_0+1)]
        window = np.hanning(2 * P_0 + 1)
        windowed_response = window * data
        audio_out[i-P_0:(i + P_0 + 1)] += windowed_response
plt.plot(audio_out, 'b')
plt.title("F_new = 100")
plt.show()

# %%
######################## YOUR CODE HERE ##############################

F_new = 300
new_epoch_spacing = int(F_s/F_new)  #P1
audio_out = np.zeros(N)

# Suggested loop
for i in range(0, N, new_epoch_spacing):
    
    #Step1: find closest epoch     
    e = np.argmin(abs(epoch_marks_orig - i))  #index
    cloest_e = epoch_marks_orig[e]            #value
    if(e == 0 or e == len(epoch_marks_orig)-1):
        pass
    else:
        #find P_0 from previous and next epochs distance
        before = epoch_marks_orig[e - 1]
        after = epoch_marks_orig[e+1]
        P_0 = int((after - before) / 2)

        #put new data in audio_out
        data = audio_data[(cloest_e - P_0):(cloest_e + P_0+1)]
        window = np.hanning(2 * P_0 + 1)
        windowed_response = window * data
        audio_out[i-P_0:(i + P_0 + 1)] += windowed_response
plt.plot(audio_out, 'b')
plt.title("F_new = 300")
plt.show()
